# %% [markdown]
# 주쥬심법 --> 주쥬신공 --> 주쥬대나이
#
#
#
# "mordern problem require mordern solutions"
#
#
#
# 제01부.주쥬심법 개요
#
# 제01부.1장.시간사용
#
# 제01부.2장.이세계관
#
# 제01부.3장.보는방법
#
#
#
# 제02부.주피터 쓰는법
#
# 제02부.1장.다운로드
#
# 제02부.2장.마크다운
#
# 제02부.3장.HTML
#
#
#
# 제03부.쥴리아 쓰는법
#
# 제03부.1장.선택사유
#
# 제03부.2장.REPL
#
# 제03부.3장.헬로월드
#
#
#
# 제04부.용어(Keyword)
#
# 제04부.1장.영어용법
#
# 제04부.2장.한글용법
#
# 제04부.3장.기호모음
#
#
#
# 제05부.형식(Type)
#
# 제05부.1장.진법사용
#
# 제05부.2장.단위사용
#
# 제05부.3장.유형사용
#
#
#
# 제06부.산수(math)
#
# 제06부.1장.단순계산
#
# 제06부.2장.논리계산
#
# 제06부.3장.복수계산
#
#
#
# 제07부.문자(char&string)
#
# 제07부.1장.문자사용
#
# 제07부.2장.복수문자
#
# 제07부.3장.복합문자
#
#
#
# 제08부.행렬(Array&tuple)
#
# 제08부.1장.의미부여(tuple & named tuple)
#
# 제08부.2장.배열조합(array)
#
# 제08부.3장.사전조합(dict)
#
# 제08부.4장.나열조합(enum)
#
# 제08부.5장.복합조합
#
#
#
# 제09부.문법
#
# 제09부.1장.다른같음
#
# 제09부.1장.1절.균등주의(equality=)
#
# 제09부.1장.2절.평등주의(egality===)
#
# 제09부.3장.3절.공정주의(equity==)
#
# 제09부.4장.강력인용
#
# 제09부.5장.다중파견
#
#
#
# 제10부.비교(condition)
#
# 제11부.반복(loop)
#
# 제12부.표현(regex)
#
# 제13부.함수(function)
#
# 제14부.모듈(module)
#
# 제15부.객체(package)
#
# 제16부.함수(function)
#
# 제17부.재귀(Recursive)
#
# 제18부.결합(combinator)
